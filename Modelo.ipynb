# %%
import pandas as pd
import numpy as np

from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
url = "dataset.csv"
x = pd.read_csv(url)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17526 entries, 0 to 17525
# Data columns (total 55 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  17526 non-null  int64
#  1   CO_REGIONA  17526 non-null  float64
#  2   CO_MUN_NOT  17526 non-null  float64
#  3   CO_UNI_NOT  17526 non-null  float64
#  4   CS_SEXO     17526 non-null  float64
#  5   CS_RACA     17526 non-null  float64
#  6   CO_RG_RESI  17526 non-null  float64
#  7   CO_MUN_RES  17526 non-null  float64
#  8   CS_ZONA     17526 non-null  float64
#  9   NOSOCOMIAL  17526 non-null  float64
#  10  FEBRE       17526 non-null  float64
#  11  TOSSE       17526 non-null  float64
#  12  GARGANTA    17526 non-null  float64
#  13  DISPNEIA    17526 non-null  float64
#  14  DESC_RESP   17526 non-null  float64
#  15  SATURACAO   17526 non-null  float64
#  16  DIARREIA    17526 non-null  float64
#  17  VOMITO      17526 non-null  float64
# ...

# %%
x.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
x.head()
# Out:
#    CO_REGIONA  CO_MUN_NOT  CO_UNI_NOT  CS_SEXO  CS_RACA  CO_RG_RESI  \
# 0      1369.0    411520.0   2586444.0      1.0      1.0      1369.0
# 1      1374.0    412770.0   4056698.0      0.0      1.0      1374.0
# 2      1369.0    411520.0   9365230.0      1.0      1.0      1369.0
# 3      1364.0    410930.0   2572443.0      1.0      1.0      1364.0
# 4      1364.0    410480.0   3293262.0      0.0      2.0      1364.0
#
#    CO_MUN_RES  CS_ZONA  NOSOCOMIAL  FEBRE  ...  CS_GESTANT  DT_SIN_PRI  \
# 0    411520.0      1.0         2.0    1.0  ...    0.666667    0.071625
# 1    412770.0      1.0         2.0    1.0  ...    0.555556    0.396694
# 2    411520.0      1.0         2.0    1.0  ...    0.666667    0.297521
# 3    410930.0      2.0         2.0    1.0  ...    0.666667    0.049587
# 4    410480.0      1.0         2.0    1.0  ...    0.555556    0.052342
#
#    DT_INTERNA  DT_COLETA    DT_PCR  DT_EVOLUCA    TEMP_T  DOSE_1_COV  \
# ...

# %%
y = x['EVOLUCAO']
x.drop(['EVOLUCAO'], axis=1, inplace=True)

x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
classificadores = [ 
    RandomForestClassifier(),
    XGBClassifier(),
    LGBMClassifier(),
    SVC(),
    DecisionTreeClassifier(),
    AdaBoostClassifier(),

]
nomes = [
    "Random Forest",
    "XGBRegressor",
    "Light GBM",
    "RBF SVM",
    "Decision Tree",
    "AdaBoost"
]

# %%
for classificador, nome in zip(classificadores, nomes):
    score = cross_val_score(classificador, x, y, cv =10)
    print(f"Accuracy of {nome} Classifier is:{score}")
    print('Média: {:} | Desvio: {:.2}'.format(np.mean(score), np.std(score)))
# Out:
# Accuracy of Random Forest Classifier is:[0.82258985 0.80661723 0.95037079 0.97261837 0.97547062 0.97832288
#  0.97146119 0.96232877 0.96803653 0.97488584]
# Média: 0.9382702060655314 | Desvio: 0.062
# C:\Users\rafar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# C:\Users\rafar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# ...
